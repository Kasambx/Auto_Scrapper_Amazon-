# %%
# !pip install autoscraper
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting autoscraper
#   Downloading autoscraper-1.1.14-py3-none-any.whl (10 kB)
# Requirement already satisfied: lxml in /usr/lib/python3/dist-packages (from autoscraper) (4.9.1)
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from autoscraper) (2.27.1)
# Requirement already satisfied: beautifulsoup4 in /usr/lib/python3/dist-packages (from bs4->autoscraper) (4.11.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=315cac15898e5cc17d3fff58b5c5edc6ea40e8734ecf2af88607898d5490d707
#   Stored in directory: /home/xamba/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# Installing collected packages: bs4, autoscraper
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# crackmapexec 5.2.2 requires impacket<0.10.0,>=0.9.23, but you have impacket 0.10.0 which is incompatible.
# crackmapexec 5.2.2 requires neo4j<5.0.0,>=4.1.1, but you have neo4j 1.7.0.dev0 which is incompatible.
# crackmapexec 5.2.2 requires pylnk3<0.4.0,>=0.3.0, but you have pylnk3 0.4.2 which is incompatible.
# Successfully installed autoscraper-1.1.14 bs4-0.0.1

# %%
from autoscraper import AutoScraper

# %%
amazon_url ="https://www.amazon.com/s?k=Cap"

wanted_list = ["$27.99","Nike Golf - Dri-FIT Swoosh Perforated Cap , 429467, White, No Size","672"]

# %%
scraper=AutoScraper()
result= scraper.build(amazon_url,wanted_list)
print(result)
# Out:
# ['$7.77', '$7.93', '$9.33', '$16.99', '$16.50', '$22.00', '$15.53', '$16.69', '$25.95', '$14.99', '$31.90', '$7.97', '$20.00', '$69.00', '$13.60', '$13.95', '$29.90', '$37.00', '$13.55', '$15.95', '$17.67', '$24.00', '$23.36', '$25.00', '$25.27', '$29.95', '$8.28', '$8.98', '$11.25', '$19.99', '$55.95', '$15.99', '$25.99', '$24.86', '$28.95', '$27.99', '$30.00', '$9.99', '$19.88', '$22.99', '$10.98', '$12.90', '$10.34', '$10.99', '$13.59', '$8.97', '$24.99', '$28.00', '$16.20', '$26.00', '$27.54', 'Falari Baseball Cap Adjustable Size for Running Workouts and Outdoor Activities All Seasons', "adidas Men's Superlite Relaxed Fit Performance Hat", 'KBETHOS Original Classic Low Profile Cotton Hat Men Women Baseball Cap Dad Hat Adjustable Unconstructed Plain Cap', "adidas Women's Saturday Relaxed Adjustable Cap", 'American Flag Trucker Hat - Snapback Hat, Baseball Cap for Men Women - Breathable Mesh Side, Adjustable Fit - for Casual Wear', 'Champion Ameritage Dad Adjustable Cap', 'Outdoor Cap Mountain Dad Hat - Unstructured Soft Cotton Cap', "Nike Men's 518015-010 Tech Swoosh Cap", 'Umeepar Smile Face Baseball Cap for Women Men Adjustable Low Profile Unstructured Cotton Dad Hat', "'47 New York Yankees MLB Brand Clean Up Adjustable", "Under Armour Boys' Blitzing 3.0 Cap", 'melin Coronado Anchored Hydro, Performance Snapback Hat, Water-Resistant Baseball Cap for Men & Women, Navy', 'Amazon Essentials Unisex Baseball Cap', 'Guwfuve 3Pack Baseball Caps, Unisex Adult Adjustable Sports Hat', 'Nike Golf Dri-Fit Swoosh Front Cap', "adidas Men's Gameday 3 Structured Stretch Fit Cap", 'PFFY 2 Packs Baseball Cap Golf Dad Hat for Men and Women', 'PUMA Evercat Icon Snapback Cap', 'NPQQUAN 1 & 2 Packs Stiff Structured Front Panels Baseball Cap Golf Dad Trucker Hats for Men Women', 'Columbia PFG Fish Flag Mesh Ball Cap-High Crown', "Nike Women's Unisex Legacy91 Tech Hat", 'YP Classics Retro Trucker Cap', "Flexfit Men's Athletic Baseball Fitted Cap", "Carhartt Men's Buffalo Sandstone Mesh Back Cap", "Carhartt Men's Canvas Cap", "adidas Women's Superlite Relaxed Fit Performance Hat", 'Ralph Lauren Mens Polo Sports Pony Logo Hat Cap (One Size, Black (White Pony))', 'MEINICY 3 Pack Washed Plain Baseball Cap, Retro Adjustable Dad Hats Gift for Men/Women,Unstructured/Cotton', 'Magpul Trucker Hat Snap Back Baseball Cap, One Size Fits Most', 'Nike Golf - Dri-FIT Swoosh Perforated Cap , 429467, White, No Size', "adidas Men's Contract Cap", 'Summer Vintage Cotton Dad Hat with Double Layer Peaks Adjustable Baseball Cap Trendy Trucker Hat for Mens Headwear', 'Carhartt mens Rugged Professional Baseball Cap, Black, One Size US', 'KBETHOS Vintage Washed Distressed Cotton Dad Hat Baseball Cap Adjustable Polo Trucker Unisex Style Headwear', 'MISSION Cooling Performance Hat- Unisex Baseball Cap, Cools When Wet', 'Baseball Cap Men Women Adjustable Plain Dad Hats Low Profile Solid Ball Cap', 'Flexfit Cotton Twill Fitted Cap', 'HGGE Womens Criss Cross Ponytail Baseball Cap Adjustable High Messy Bun Ponycap Quick Drying Hat', "Hurley One & Only Men's Hat", "Under Armour Men's Blitzing 3.0 Cap", 'Fishing Trucker Hat for Men,Embroidered Design,Ideal Gifts Hats for Outdoor and Fishing', "'47 Brand Los Angeles LA Dodgers Clean Up Hat Cap Washed (Vintage) Camo/White", "Under Armour Men's Heathered Blitzing 3.0 Cap", "Timberland Men's Cotton Canvas Baseball Cap", "Puma Women's Evercat Running Cap", "Circle Mama Trucker Hat Adjustable Snapback Mom Hat Mother's Day Birthday Gift", "adidas Originals Women's Relaxed Fit Adjustable Strapback Cap 2020", "Under Armour Men's Iso-chill ArmourVent Fitted Baseball Cap", '9,544', 'Delivery Fri, Oct 7', '12,595', '20,797', '11,944', '1,218', '16,887', '6,412', '1,281', '118', '$24.91 delivery', '2,832', '$27.34 delivery', '5,191', '72', '954', '$32.26 delivery', '1,205', '1,079', '967', '1,291', '1,955', '242', '14,663', '814', '10,596', '38,145', '9,224', '24,054', '4,868', '162', '4,319', '603', '672', '$28.91 delivery', '1,655', '187' ...

# %%
scraper.get_result_similar(amazon_url,grouped=True)
# Out:
# {'rule_pqwr': ['$7.77',
#   '$7.93',
#   '$9.33',
#   '$16.99',
#   '$16.50',
#   '$22.00',
#   '$15.53',
#   '$16.69',
#   '$25.95',
#   '$14.99',
#   '$31.90',
#   '$7.97',
#   '$20.00',
#   '$69.00',
#   '$13.60',
#   '$13.95',
#   '$29.90',
#   '$37.00',
#   '$13.55',
#   '$15.95',
#   '$17.67',
#   '$24.00',
#   '$15.95',
#   '$23.36',
#   '$25.00',
#   '$25.27',
#   '$29.95',
#   '$8.28',
#   '$8.98',
#   '$11.25',
#   '$19.99',
#   '$19.99',
#   '$55.95',
#   '$15.99',
#   '$25.99',
#   '$24.86',
#   '$28.95',
#   '$27.99',
#   '$30.00',
#   '$9.99',
#   '$19.99',
#   '$13.95',
#   '$19.88',
#   '$22.99',
#   '$10.98',
#   '$12.90',
#   '$10.34',
#   '$10.99',
#   '$13.59',
#   '$16.99',
#   '$25.99',
#   '$8.97',
#   '$25.00',
#   '$16.99',
#   '$24.99',
#   '$25.00',
#   '$28.00',
#   '$16.20',
#   '$24.00',
#   '$24.99',
#   '$26.00',
#   '$27.54'],
#  'rule_rp4u': ['$7.77',
#   '$7.93',
#   '$9.33',
#   '$16.99',
#   '$16.50',
#   '$22.00',
#   '$15.53',
#   '$16.69',
#   '$25.95',
#   '$14.99',
#   '$31.90',
#   '$7.97',
#   '$20.00',
#   '$69.00',
#   '$13.60',
#   '$13.95',
#   '$29.90',
#   '$37.00',
#   '$13.55',
#   '$15.95',
#   '$17.67',
#   '$24.00',
#   '$15.95',
#   '$23.36',
#   '$25.00',
#   '$25.27',
#   '$29.95',
#   '$8.28',
#   '$8.98',
#   '$11.25',
#   '$19.99',
#   '$19.99',
#   '$55.95',
#   '$15.99',
#   '$25.99',
#   '$24.86',
#   '$28.95',
#   '$27.99',
#   '$30.00',
#   '$9.99',
#   '$19.99',
#   '$13.95',
#   '$19.88',
#   '$22.99',
#   '$10.98',
#   '$12.90',
#   '$10.34',
#   '$10.99',
#   '$13.59',
#   '$16.99',
#   '$25.99',
#   '$8.97',
#   '$25.00',
#   '$16.99',
#   '$24.99',
#   '$25.00',
#   '$28.00',
#   '$16.20',
#   '$24.00',
#   '$24.99',
#   '$26.00',
#   '$27.54'],
#  'rule_40wn': ['$27.99', '$9.99'],
#  'rule_xxxc': ['$27.99', '$9.99'],
#  'rule_yno4': ['Falari Baseball Cap Adjustable Size for Running Workouts and Outdoor Activities All Seasons',
#   "adidas Men's Superlite Relaxed Fit Performance Hat",
#   'KBETHOS Original Classic Low Profile Cotton Hat Men Women Baseball Cap Dad Hat Adjustable Unconstructed Plain Cap',
#   "adidas Women's Saturday Relaxed Adjustable Cap",
#   'American Flag Trucker Hat - Snapback Hat, Baseball Cap for Men Women - Breathable Mesh Side, Adjustable Fit - for Casual Wear',
#   'Champion Ameritage Dad Adjustable Cap',
#   'Outdoor Cap Mountain Dad Hat - Unstructured Soft Cotton Cap',
#   "Nike Men's 518015-010 Tech Swoosh Cap",
#   'Umeepar Smile Face Baseball Cap for Women Men Adjustable Low Profile Unstructured Cotton Dad Hat',
#   "'47 New York Yankees MLB Brand Clean Up Adjustable",
#   "Under Armour Boys' Blitzing 3.0 Cap",
#   'melin Coronado Anchored Hydro, Performance Snapback Hat, Water-Resistant Baseball Cap for Men & Women, Navy',
#   'Amazon Essentials Unisex Baseball Cap',
#   'Guwfuve 3Pack Baseball Caps, Unisex Adult Adjustable Sports Hat',
#   'Nike Golf Dri-Fit Swoosh Front Cap',
#   "adidas Men's Gameday 3 Structured Stretch Fit Cap",
#   'PFFY 2 Packs Baseball Cap Golf Dad Hat for Men and Women',
#   'PUMA Evercat Icon Snapback Cap',
#   'NPQQUAN 1 & 2 Packs Stiff Structured Front Panels Baseball Cap Golf Dad Trucker Hats for Men Women',
#   'Columbia PFG Fish Flag Mesh Ball Cap-High Crown',
#   "Nike Women's Unisex Legacy91 Tech Hat",
#   'YP Classics Retro Trucker Cap',
#   "Flexfit Men's Athletic Baseball Fitted Cap",
#   "Carhartt Men's Buffalo Sandstone Mesh Back Cap",
#   "Carhartt Men's Canvas Cap",
#   "adidas Women's Superlite Relaxed Fit Performance Hat",
#   'Ralph Lauren Mens Polo Sports Pony Logo Hat Cap (One Size, Black (White Pony))',
#   'MEINICY 3 Pack Washed Plain Baseball Cap, Retro Adjustable Dad Hats Gift for Men/Women,Unstructured/Cotton',
#   'Magpul Trucker Hat Snap Back Baseball Cap, One Size Fits Most',
#   'Nike Golf - Dri-FIT Swoosh Perforated Cap , 429467, White, No Size',
#   "adidas Men's Contract Cap",
#   'Summer Vintage Cotton Dad Hat with Double Layer Peaks Adjustable Baseball Cap Trendy Trucker Hat for Mens Headwear',
#   'Carhartt mens Rugged Professional Baseball Cap, Black, One Size US',
#   'KBETHOS Vintage Washed Distressed Cotton Dad Hat Baseball Cap Adjustable Polo Trucker Unisex Style Headwear',
#   'MISSION Cooling Performance Hat- Unisex Baseball Cap, Cools When Wet',
#   'Baseball Cap Men Women Adjustable Plain Dad Hats Low Profile Solid Ball Cap',
#   'Flexfit Cotton Twill Fitted Cap',
#   'HGGE Womens Criss Cross Ponytail Baseball Cap Adjustable High Messy Bun Ponycap Quick Drying Hat',
#   "Hurley One & Only Men's Hat",
#   "Under Armour Men's Blitzing 3.0 Cap",
#   'Fishing Trucker Hat for Men,Embroidered Design,Ideal Gifts Hats for Outdoor and Fishing',
#   "'47 Brand Los Angeles LA Dodgers Clean Up Hat Cap Washed (Vintage) Camo/White",
#   "Under Armour Men's Heathered Blitzing 3.0 Cap",
#   "Timberland Men's Cotton Canvas Baseball Cap",
#   "Puma Women's Evercat Running Cap",
#   "Circle Mama Trucker Hat Adjustable Snapback Mom Hat Mother's Day Birthday Gift",
#   "adidas Originals Women's Relaxed Fit Adjustable Strapback Cap 2020",
#   "Under Armour Men's Iso-chill ArmourVent Fitted Baseball Cap"],
#  'rule_3tty': ['Falari Baseball Cap Adjustable Size for Running Workouts and Outdoor Activities All Seasons',
#   "adidas Men's Superlite Relaxed Fit Performance Hat",
#   'KBETHOS Original Classic Low Profile Cotton Hat Men Women Baseball Cap Dad Hat Adjustable Unconstructed Plain Cap',
#   "adidas Women's Saturday Relaxed Adjustable Cap",
#   'American Flag Trucker Hat - Snapback Hat, Baseball Cap for Men Women - Breathable Mesh Side, Adjustable Fit - for Casual Wear',
#   'Champion Ameritage Dad Adjustable Cap',
#   'Outdoor Cap Mountain Dad Hat - Unstructured Soft Cotton Cap',
#   "Nike Men's 518015-010 Tech Swoosh Cap",
#   'Umeepar Smile Face Baseball Cap for Women Men Adjustable Low Profile Unstructured Cotton Dad Hat',
#   "'47 New York Yankees MLB Brand Clean Up Adjustable",
#   "Under Armour Boys' Blitzing 3.0 Cap",
#   'melin Coronado Anchored Hydro, Performance Snapback Hat, Water-Resistant Baseball Cap for Men & Women, Navy',
#   'Amazon Essentials Unisex Baseball Cap',
#   'Guwfuve 3Pack Baseball Caps, Unisex Adult Adjustable Sports Hat',
#   'Nike Golf Dri-Fit Swoosh Front Cap',
#   "adidas Men's Gameday 3 Structured Stretch Fit Cap",
#   'PFFY 2 Packs Baseball Cap Golf Dad Hat for Men and Women',
#   'PUMA Evercat Icon Snapback Cap',
#   'NPQQUAN 1 & 2 Packs Stiff Structured Front Panels Baseball Cap Golf Dad Trucker Hats for Men Women',
#   'Columbia PFG Fish Flag Mesh Ball Cap-High Crown',
#   "Nike Women's Unisex Legacy91 Tech Hat",
#   'YP Classics Retro Trucker Cap',
#   "Flexfit Men's Athletic Baseball Fitted Cap",
#   "Carhartt Men's Buffalo Sandstone Mesh Back Cap",
#   "Carhartt Men's Canvas Cap",
#   "adidas Women's Superlite Relaxed Fit Performance Hat",
#   'Ralph Lauren Mens Polo Sports Pony Logo Hat Cap (One Size, Black (White Pony))',
#   'MEINICY 3 Pack Washed Plain Baseball Cap, Retro Adjustable Dad Hats Gift for Men/Women,Unstructured/Cotton',
#   'Magpul Trucker Hat Snap Back Baseball Cap, One Size Fits Most',
#   'Nike Golf - Dri-FIT Swoosh Perforated Cap , 429467, White, No Size',
#   "adidas Men's Contract Cap",
#   'Summer Vintage Cotton Dad Hat with Double Layer Peaks Adjustable Baseball Cap Trendy Trucker Hat for Mens Headwear',
#   'Carhartt mens Rugged Professional Baseball Cap, Black, One Size US',
#   'KBETHOS Vintage Washed Distressed Cotton Dad Hat Baseball Cap Adjustable Polo Trucker Unisex Style Headwear',
#   'MISSION Cooling Performance Hat- Unisex Baseball Cap, Cools When Wet',
#   'Baseball Cap Men Women Adjustable Plain Dad Hats Low Profile Solid Ball Cap',
#   'Flexfit Cotton Twill Fitted Cap',
#   'HGGE Womens Criss Cross Ponytail Baseball Cap Adjustable High Messy Bun Ponycap Quick Drying Hat',
#   "Hurley One & Only Men's Hat",
#   "Under Armour Men's Blitzing 3.0 Cap",
#   'Fishing Trucker Hat for Men,Embroidered Design,Ideal Gifts Hats for Outdoor and Fishing',
#   "'47 Brand Los Angeles LA Dodgers Clean Up Hat Cap Washed (Vintage) Camo/White",
#   "Under Armour Men's Heathered Blitzing 3.0 Cap",
#   "Timberland Men's Cotton Canvas Baseball Cap",
#   "Puma Women's Evercat Running Cap",
#   "Circle Mama Trucker Hat Adjustable Snapback Mom Hat Mother's Day Birthday Gift",
#   "adidas Originals Women's Relaxed Fit Adjustable Strapback Cap 2020",
#   "Under Armour Men's Iso-chill ArmourVent Fitted Baseball Cap"],
#  'rule_atx3': ['9,544',
#   '12,595',
#   '20,797',
#   '11,944',
#   '1,218',
#   '16,887',
#   '6,412',
#   '1,281',
#   '118',
#   '2,832',
#   '5,191',
#   '72',
#   '954',
#   '1,205',
#   '1,079',
#   '967',
#   '1,291',
#   '1,955',
#   '242',
#   '14,663',
#   '814',
#   '10,596',
#   '38,145',
#   '9,224',
#   '24,054',
#   '4,868',
#   '162',
#   '4,319',
#   '603',
#   '672',
#   '1,655',
#   '187',
#   '9,462',
#   '13,862',
#   '9,634',
#   '2,396',
#   '9,799',
#   '2,601',
#   '1,815',
#   '55,497',
#   '2',
#   '341',
#   '9,295',
#   '1,320',
#   '4,175',
#   '49',
#   '3,860',
#   '1,761']}

# %%
scraper.set_rule_aliases({'rule_jzvh':'Title','rule_b65c':'Price','rule_xqsd':'Rating'})
scraper.keep_rules(['rule_jzvh','rule_b65c','rule_xqsd'])
scraper.save('amazon-search')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5773/182814002.py in <module>
# ----> 1 scraper.set_rule_aliases({'rule_jzvh':'Title','rule_b65c':'Price','rule_xqsd':'Rating'})
#       2 scraper.keep_rules(['rule_jzvh','rule_b65c','rule_xqsd'])
#       3 scraper.save('amazon-search')
#
# ~/.local/lib/python3.10/site-packages/autoscraper/auto_scraper.py in set_rule_aliases(self, rule_aliases)
#     717         id_to_stack = {stack["stack_id"]: stack for stack in self.stack_list}
#     718         for rule_id, alias in rule_aliases.items():
# --> 719             id_to_stack[rule_id]["alias"] = alias
#     720
#     721     def generate_python_code(self):
#
# KeyError: 'rule_b65c'

# %%
results =scraper.get_result_similar('',group_by_alias= True)

# %%
results['Title']
# Out:
# ['Amazon Essentials Unisex Baseball Cap',
#  'MRACSIY Mens Baseball Cap Winter Caps for Head Circumference 57-61cm',
#  'PLIOPYIK White Black Baseball Cap, Unisex Adjustable Womens Mens Baseball Cap Golf Dad Hat',
#  'American Flag Trucker Hat - Snapback Hat, Baseball Cap for Men Women - Breathable Mesh Side, Adjustable Fit - for Casual Wear',
#  "Home Prefer Men's Sun Hat UPF50+ Adjustable Cotton Washed Baseball Cap Unisex",
#  'Edoneery Men Women Plain Cotton Adjustable Washed Twill Low Profile Baseball Cap Hat(A1008)',
#  'OAKFARM Baseball Cap Mens Hats for Women Distressed Washed Denim Vintage Ball Caps Summer Sun Dad Hat Unisex Adjustable',
#  'Macucop Funny Giraffe Outdoor Sport Adjustable Hat Cowboy Cap Unisex Printed Hat',
#  'TSSGBL Vintage Cotton Washed Adjustable Baseball Caps Men and Women, Unstructured Low Profile Plain Classic Retro Dad Hat',
#  'MRACSIY Mens Baseball Cap Winter Caps for Head Circumference 56-60cm',
#  'Finphoon 5 Gallon Water Jug Caps Reusable ,4Pcs Silicone Spill Resistant Water Bottle Caps Fits 55mm Bottles',
#  'Poolbeanies, Designer Fabric Swim Cap, Swan Lake, Single Cap']
